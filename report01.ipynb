# %% [markdown]
# # 第1回レポート課題
#
#
# 提出物：
#
# - report01.ipynb（このノートブック）
#   - ノートブックに直接コードを書いて実行できる
#   - コードを実行した結果の状態で保存して提出すること
# - レポート
#   - 形式：A4縦，PDFファイル1つ（複数ファイルやwordファイルは受け付けない）
#   - 1ページ目冒頭に，氏名・学生番号・所属学科/分野/コース・授業名・課題名・出題授業日を明記すること
#   - 各課題（「課題1-07」「課題1-08」など）を区別できるようにすること
#   - 含める内容
#     - コードの抜粋とその説明
#     - 実行結果（テキスト出力，プロット等）とその説明
#     - 各課題で指定された内容とその説明
#   - レポート作成上の注意事項:
#     - **レポートにはできるだけ丁寧な説明を含めること**

# %% [markdown]
# なお今回の課題のうち，以下の課題1-01〜1-06についてはコード（実行結果付きのノートブック）の提出だけで良い．

# %% [markdown]
# ## 課題1-01
#
# 与えられたリストの要素の値に応じて以下に示すようなメッセージが表示されるコードを作成せよ．
#
# | 値          | メッセージ              |
# |-------------|-------------------------|
# | 0未満（負） | Error (Negative value)  |
# | 0以上 - 60未満      | Your grade is F         |
# | 60以上 - 70未満     | Your grade is D         |
# | 70以上 - 80未満     | Your grade is C         |
# | 80以上 - 90未満     | Your grade is B         |
# | 90以上 - 100未満    | Your grade is A         |
# | 100以上     | Error (Larger than 100) |

# %%
score_list = [122, 74, -11, 67, 33, 80, 92, 100, 67, 99]


for score in score_list:

    #
    # 以下にコードを作成
    #

    if score < 0:
        print("****")  # これはダミーです

# %% [markdown]
# ## 課題1-02
#
# 与えられたリストの要素の平均を表示するコードを作成せよ．
#
# 注意：リストの長さは任意である．

# %%
value_list = [122, 74, -11, 67, 33, 80, 92, 100, 67, 99]

#
# 以下にコードを作成
#

# %% [markdown]
# ## 課題1-03
#
# 直角三角形の斜辺以外の辺の長さ`a`, `b`から面積を計算する関数`area_right_triangle(a, b)`を追加せよ．

# %%
def area_right_triangle(a, b):
    #
    # 以下にコードを作成
    #

    area = 0  # これはダミーです
    
    return area


a = 1
b = 2

print("area_right_triangle({:.02f}, {:.03f}) = {:.06f}".format(
    a, b, area_right_triangle(a, b)))
# Out:
# area_right_triangle(1.00, 2.000) = 0.000000

# %% [markdown]
# ## 課題1-04
#
# 課題1-03において，`format()`の指定子を様々に変更して，表示がどう変化するか確かめよ．

# %% [markdown]
# ## 課題1-05
#
# 3つの変数`a`, `b`, `c`に対して，`a`を`b`に，`b`を`c`に, `c`を`a`に代入する入れ替えを実行する関数`cycle_swap`を作成せよ．

# %%
def cycle_swap(a, b, c):
    #
    # 以下にコードを作成
    #

    return 0, 0, 0  # これはダミーです



a = 1
b = 2
c = 3

print("swap {}, {}, {}".format(a, b, c), end="")
a, b, c = cycle_swap(a, b, c)
print(" ==> {}, {}, {}".format(a, b, c))
# Out:
# swap 1, 2, 3 ==> 0, 0, 0

# %% [markdown]
# ## 課題1-06
#
# 与えられたリストの要素の平均を求め，リストのそれぞれの要素から平均値を引いた値を表示せよ．

# %%
value_list = [10, 20, 30, 40, 50]
print("list: ", value_list)

#
# 以下にコードを作成
#






print("processed list: ", value_list)
# Out:
# list:  [10, 20, 30, 40, 50]
# processed list:  [10, 20, 30, 40, 50]

# %% [markdown]
# ## 課題1-07：2次方程式
#
#
#
# 2次方程式
# $f(x) = x^2 - 2 a x + b = 0$, $a > 0$, $D = a^2 - b > 0$
# の解
# $$
# \begin{align*}
#  x_1 &= a + \sqrt{D}\\
#  x_2 &= a - \sqrt{D}
# \end{align*}
# $$
# の計算を考える．
#
# $x_2$の計算は$|b|$が$a^2$に比べて小さいときに桁落ちが発生する可能性がある．
#
# 以下のコードには，入力された`a`と`b`に対して上記の方法で2次方程式の解を計算する関数` solve_quadratic_equation1`が用意されている．
#
# 桁落ちの発生しにくい計算式を導出し，`solve_quadratic_equation2`に実装せよ．
#
#
#
#
# - レポートに含める内容
#   - 導出した計算式
#   - 異なる$a$, $b$に対する$x_2$の計算結果を記載した以下の表
#     - （掲載する表の形式は全く同じでなくても良いが，各セルに相当する値が確認できるように作成すること）
#
#
#
# |            |     | 解の公式による計算 |          | 改善した計算法    |          |
# |------------|-----|-----------------|----------|----------------|----------|
# | $a$        | $b$ | $x_2$           | $f(x_2)$ | $x_2$          | $f(x_2)$ |
# | 10         | 1   |                 |          |                |          |
# | 100        | 1   |                 |          |                |          |
# | 1000       | 1   |                 |          |                |          |
# | 10000      | 1   |                 |          |                |          |
# | 100000     | 1   |                 |          |                |          |
# | 1000000    | 1   |                 |          |                |          |
# | 10000000   | 1   |                 |          |                |          |
# | 100000000  | 1   |                 |          |                |          |
# | 1000000000 | 1   |                 |          |                |          |

# %%
import numpy as np

def solve_quadratic_equation1(a, b):
    """通常の公式で解を求める

    Args:
        a (float): aの値
        b (float): bの値

    Returns:
        x_1 (float): 解x_1の値
        x_2 (float): 解x_2の値
    """

    D = a * a - b
    if D < 0:
        return False, False

    x1 = a + np.sqrt(D)
    x2 = a - np.sqrt(D)

    return x1, x2


def solve_quadratic_equation2(a, b):
    """通常の公式で解を求める

    Args:
        a (float): aの値
        b (float): bの値

    Returns:
        x_1 (float): 解x_1の値
        x_2 (float): 解x_2の値
    """
    
    # 
    # 以下にコードを作成
    # 

    x1 = 0  # これはダミーです
    x2 = 0  # これはダミーです






    return x1, x2



# 方程式の係数を設定する
print("Solve quadratic equation x^2 - 2 a x + b = 0")
a = 10000000
b = 1
print("a=", a)
print("b=", b)


x1, x2 = solve_quadratic_equation1(a, b)
if x1 == False:
    print("error: invalid equation")
else:
    print("Naive calculation:")
    print(" x = {}, {}".format(x1, x2))
    print(" f(x2) = ", x2 * x2 - 2 * a * x2 + b)


x1, x2 = solve_quadratic_equation2(a, b)
if x1 == False:
    print("error: invalid equation")
else:
    print("Improved calculation:")
    print(" x = {}, {}".format(x1, x2))
    print(" f(x2) = ", x2 * x2 - 2 * a * x2 + b)

# %% [markdown]
# ## 課題1-08：マシンイプシロン
#
#
#
# 浮動小数点演算において，非常に小さな正の数$\epsilon$に対して$1 + \epsilon$を行うと演算の結果が$1 + \epsilon = 1$となってしまう．
# この現象は「情報落ち」と呼ばれる誤差の一種である．
#
# ある$\epsilon = 2^n$（$n$は整数）を考えたとき，$1 + \epsilon$の結果が$1 + \epsilon > 1$となる（つまり，演算の前後できちんと値が変化する）ような最小の$\epsilon$をマシンイプシロンと呼ぶ．
#
# 以下のアルゴリズムによってマシンイプシロンの値を確かめることができる．
#
# 1. 変数$\epsilon$を$1$で初期化する
# 2. $1 + \epsilon > 1$が真ならばStep3へ，偽ならStep4へ進む
# 3. $\epsilon \leftarrow \epsilon / 2$として，値を表示してから，Step2へ戻る
# 4. $\epsilon \leftarrow 2 \epsilon$をマシンイプシロンとして表示する
#
# 上のアルゴリズムのプログラムを作成し，マシンイプシロンを表示せよ．
#
# また，ステップ2の評価式（$1 + \epsilon > 1$）の両辺の1を，別の値（0や10，1e5など）に変更して，得られた結果を考察せよ．
#
#
#
# - レポートに含める内容
#   - 作成したコードによって求められたマシンイプシロン
#   - 1以外の値に変更した場合の結果とその考察

# %%
eps = 1.0

while 1 + eps > 1:

    #
    # 以下にコードを作成
    #

    eps = 0  # これはダミーです





print("eps=", eps)
